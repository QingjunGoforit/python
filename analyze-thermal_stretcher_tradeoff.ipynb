# %%
import numpy as np
import cmath
import math
import matplotlib.pyplot as plt

length_fiber=np.linspace(1,10,40)
print("length of fiber="+str(length_fiber))
swing_of_temp=0.04 #temp swing
range_of_temp=0.6 #polarization stable temp
phase_per_swing=length_fiber*swing_of_temp*113.63
print('phase per swing='+str(phase_per_swing))
total_phase=phase_per_swing*range_of_temp/swing_of_temp

size=20
#figHandler, axHandler = plt.subplots(1, 1, layout='constrained')
plt.figure(figsize=(5,4))
plt.plot(length_fiber, phase_per_swing, 'r', label="phase vibration per swing")
plt.plot(length_fiber, 10+np.zeros(len(length_fiber)), '-.r', label="phase=10rad")
#plt.plot(length_fiber, total_phase, 'k', label='total phase within temp range')
#plt.plot(length_fiber, 500+np.zeros(len(length_fiber)), '-.k', label='total phase =500')

#plt.grid(True); 
plt.xlabel('fiber length',fontsize = size); plt.ylabel('phase',fontsize = size); 
plt.legend(fontsize=10,loc='upper right')
plt.tick_params(axis='both', which='major', labelsize=10)
#plt.title('input power=1 on arm1',fontsize = size)
plt.show()

# fig = plt.figure(figsize=(10,4))
# fig,ax = plt.subplots()
# ax.plot(phase_angle_two[0:]/np.pi,I1[0:],color="red")
# ax.set_xlabel("phase of arm 2 in pi", fontsize = 10)
# ax.set_ylabel("I1",color="red",fontsize=20)
# ax.tick_params(axis='both', which='major', labelsize=10)
# ax2=ax.twinx()
# ax.plot(phase_angle_two[0:]/np.pi,I2[0:],color="blue")
# ax.set_xlabel("phase of arm 2 in pi", fontsize = 10)
# ax.set_ylabel("I2",color="red",fontsize=20)
# ax.tick_params(axis='both', which='major', labelsize=10)
# fig.set_figwidth(10)
# Out:
# length of fiber=[ 1.          1.23076923  1.46153846  1.69230769  1.92307692  2.15384615
#   2.38461538  2.61538462  2.84615385  3.07692308  3.30769231  3.53846154
#   3.76923077  4.          4.23076923  4.46153846  4.69230769  4.92307692
#   5.15384615  5.38461538  5.61538462  5.84615385  6.07692308  6.30769231
#   6.53846154  6.76923077  7.          7.23076923  7.46153846  7.69230769
#   7.92307692  8.15384615  8.38461538  8.61538462  8.84615385  9.07692308
#   9.30769231  9.53846154  9.76923077 10.        ]
# phase per swing=[ 4.5452      5.59409231  6.64298462  7.69187692  8.74076923  9.78966154
#  10.83855385 11.88744615 12.93633846 13.98523077 15.03412308 16.08301538
#  17.13190769 18.1808     19.22969231 20.27858462 21.32747692 22.37636923
#  23.42526154 24.47415385 25.52304615 26.57193846 27.62083077 28.66972308
#  29.71861538 30.76750769 31.8164     32.86529231 33.91418462 34.96307692
#  36.01196923 37.06086154 38.10975385 39.15864615 40.20753846 41.25643077
# ...
